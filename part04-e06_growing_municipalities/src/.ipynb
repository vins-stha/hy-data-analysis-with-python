# %%
import pandas as pd
df = pd.read_csv("municipal.tsv", index_col="Region 2018", sep ="\t")
df
# Out:
#                                                     Population  \
# Region 2018
# WHOLE COUNTRY                                          5513130
# Akaa                                                     16769
# Alajärvi                                                  9831
# Alavieska                                                 2610
# Alavus                                                   11713
# Asikkala                                                  8248
# Askola                                                    4990
# Aura                                                      3991
# Brändö                                                     452
# Eckerö                                                     948
# Enonkoski                                                 1416
# Enontekiö                                                 1893
# Espoo                                                   279044
# Eura                                                     11910
# ...
