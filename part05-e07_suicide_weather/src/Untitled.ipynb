# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("who_suicide_statistics.csv")
df.head()
html = pd.read_html("List_of_countries_by_average_yearly_temperature.html",index_col ="Country", header=0)
#html =  pd.read_html("http://queirozf.com/entries/pandas-dataframe-groupby-examples"
type(html)
a = html[0].index.sort_values()
html[0].index = html[0].index.sort_values()
type(html[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.read_csv("who_suicide_statistics.csv",sep=",")
grouped_data =df.groupby("country")[["suicides_no"]].apply(lambda x: np.mean(x.div(df["population"])))
grouped_data.rename(index={"country":"COUNTRY"})
# Out:
#                                     suicides_no   0   1   2   3   4   5   6  \
# country
# Albania                                     NaN NaN NaN NaN NaN NaN NaN NaN
# Anguilla                                    NaN NaN NaN NaN NaN NaN NaN NaN
# Antigua and Barbuda                         NaN NaN NaN NaN NaN NaN NaN NaN
# Argentina                                   NaN NaN NaN NaN NaN NaN NaN NaN
# Armenia                                     NaN NaN NaN NaN NaN NaN NaN NaN
# Aruba                                       NaN NaN NaN NaN NaN NaN NaN NaN
# Australia                                   NaN NaN NaN NaN NaN NaN NaN NaN
# Austria                                     NaN NaN NaN NaN NaN NaN NaN NaN
# Azerbaijan                                  NaN NaN NaN NaN NaN NaN NaN NaN
# Bahamas                                     NaN NaN NaN NaN NaN NaN NaN NaN
# Bahrain                                     NaN NaN NaN NaN NaN NaN NaN NaN
# ...
