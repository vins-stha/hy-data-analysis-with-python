# %%
import pandas as pd
df = pd.read_csv("UK-top40-1964-1-2.tsv", sep="\t")
df.head()
# Out:
#    Pos LW                         Title                    Artist  \
# 0    1  1      I WANT TO HOLD YOUR HAND               THE BEATLES
# 1    2  6                 GLAD ALL OVER       THE DAVE CLARK FIVE
# 2    3  2                 SHE LOVES YOU               THE BEATLES
# 3    4  3          YOU WERE MADE FOR ME  FREDDIE AND THE DREAMERS
# 4    5  9  TWENTY FOUR HOURS FROM TULSA               GENE PITNEY
#
#         Publisher  Peak Pos  WoC
# 0      PARLOPHONE         1    5
# 1        COLUMBIA         2    7
# 2      PARLOPHONE         1   19
# 3        COLUMBIA         3    9
# 4  UNITED ARTISTS         5    5

# %%
df_10 = df.iloc[:10,[2,3]]
wh = pd.read_csv("https://www.cs.helsinki.fi/u/jttoivon/dap/data/fmi/kumpula-weather-2017.csv")
wh.head()
july = wh.loc[wh["m"]==7,:]

july.head()
# Out:
#      Year  m  d   Time Time zone  Precipitation amount (mm)  Snow depth (cm)  \
# 181  2017  7  1  00:00       UTC                        0.1             -1.0
# 182  2017  7  2  00:00       UTC                       -1.0             -1.0
# 183  2017  7  3  00:00       UTC                        2.2             -1.0
# 184  2017  7  4  00:00       UTC                        0.9             -1.0
# 185  2017  7  5  00:00       UTC                       -1.0             -1.0
#
#      Air temperature (degC)
# 181                    14.1
# 182                    16.4
# 183                    14.5
# 184                    14.1
# 185                    14.0

# %%
zero = wh.loc[(wh["Air temperature (degC)"]<0.0),:]
zero.shape[0]
# Out:
# 49

# %%
wh2 = wh.drop(["Year", "m", "d"], axis=1)  # taking averages over these is not very interesting
wh2.mean()
wh2
zero
# Out:
#      Year   m   d   Time Time zone  Precipitation amount (mm)  \
# 1    2017   1   2  00:00       UTC                        4.4
# 2    2017   1   3  00:00       UTC                        6.6
# 3    2017   1   4  00:00       UTC                       -1.0
# 4    2017   1   5  00:00       UTC                       -1.0
# 5    2017   1   6  00:00       UTC                        0.3
# 6    2017   1   7  00:00       UTC                        5.3
# 7    2017   1   8  00:00       UTC                       -1.0
# 10   2017   1  11  00:00       UTC                       -1.0
# 11   2017   1  12  00:00       UTC                        8.0
# 14   2017   1  15  00:00       UTC                       -1.0
# 15   2017   1  16  00:00       UTC                       -1.0
# 16   2017   1  17  00:00       UTC                        0.2
# 19   2017   1  20  00:00       UTC                        0.3
# 20   2017   1  21  00:00       UTC                        0.4
# ...

# %%
wh2.describe()
wh2["Snow depth (cm)"].min()
wh2["Air temperature (degC)"].min()
#wh2.max(level= 1)
# Out:
# -17.8

# %%
def triple(i):
	t = i * 3
	return t
def square(i):
	s = i ** 2
	return s
 

for j in range(1,11):
	print(f"triple({j})=={triple(j)} square({j})=={square(j)}")
	if square(j) >=triple(j):
		break
# Out:
# triple(1)==3 square(1)==1
# triple(2)==6 square(2)==4
# triple(3)==9 square(3)==9
