# %%
import pandas as pd
df = pd.read_csv("Helsingin_pyorailijamaarat.csv",sep=";")
df.tail()
# Out:
#       Päivämäärä  Auroransilta  Eteläesplanadi  Huopalahti (asema)  \
# 37161        NaN           NaN             NaN                 NaN
# 37162        NaN           NaN             NaN                 NaN
# 37163        NaN           NaN             NaN                 NaN
# 37164        NaN           NaN             NaN                 NaN
# 37165        NaN           NaN             NaN                 NaN
#
#        Kaisaniemi/Eläintarhanlahti  Kaivokatu  Kulosaaren silta et.  \
# 37161                          NaN        NaN                   NaN
# 37162                          NaN        NaN                   NaN
# 37163                          NaN        NaN                   NaN
# 37164                          NaN        NaN                   NaN
# 37165                          NaN        NaN                   NaN
#
#        Kulosaaren silta po.   Kuusisaarentie  Käpylä, Pohjoisbaana  ...  \
# 37161                    NaN             NaN                   NaN  ...
# 37162                    NaN             NaN                   NaN  ...
# 37163                    NaN             NaN                   NaN  ...
# 37164                    NaN             NaN                   NaN  ...
# 37165                    NaN             NaN                   NaN  ...
#
#        Munkkiniemen silta eteläpuoli  Munkkiniemi silta pohjoispuoli  \
# 37161                            NaN                             NaN
# 37162                            NaN                             NaN
# 37163                            NaN                             NaN
# 37164                            NaN                             NaN
# 37165                            NaN                             NaN
#
#        Heperian puisto/Ooppera  Pitkäsilta itäpuoli  Pitkäsilta länsipuoli  \
# 37161                      NaN                  NaN                    NaN
# 37162                      NaN                  NaN                    NaN
# 37163                      NaN                  NaN                    NaN
# 37164                      NaN                  NaN                    NaN
# 37165                      NaN                  NaN                    NaN
#
#        Lauttasaaren silta pohjoispuoli  Ratapihantie  Viikintie  Baana  \
# 37161                              NaN           NaN        NaN    NaN
# 37162                              NaN           NaN        NaN    NaN
# 37163                              NaN           NaN        NaN    NaN
# 37164                              NaN           NaN        NaN    NaN
# 37165                              NaN           NaN        NaN    NaN
#
#        Unnamed: 21
# 37161          NaN
# 37162          NaN
# 37163          NaN
# 37164          NaN
# 37165          NaN
#
# [5 rows x 22 columns]

# %%
states = ["United Kingdom","Finland","USA","Sweden","Germany","Russia"]
year = [0,1917,1776,1523,0,1992]
heads = ["","Niinistö","Trump","","Steinmeier","Putin"]
data = { "State":states, "Year of Independence":year, "President":heads}
df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-7e68000f9eb0> in <module>
#       3 heads = ["","Niinistö","Trump","","Steinmeier","Putin"]
#       4 data = { "State":states, "Year of Independence":year, "President":heads}
# ----> 5 df = pd.DataFrame(data, index="State")
#       6 df
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      51         index = extract_index(arrays)
#      52     else:
# ---> 53         index = ensure_index(index)
#      54
#      55     # don't force copy because getting jammed in an ndarray anyway
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5376             index_like = copy(index_like)
#    5377
# -> 5378     return Index(index_like)
#    5379
#    5380
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     466                          **kwargs)
#     467         elif data is None or is_scalar(data):
# --> 468             cls._scalar_data_error(data)
#     469         else:
#     470             if tupleize_cols and is_list_like(data):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _scalar_data_error(cls, data)
#    3797         raise TypeError('{0}(...) must be called with a collection of some '
#    3798                         'kind, {1} was passed'.format(cls.__name__,
# -> 3799                                                       repr(data)))
#    3800
#    3801     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, 'State' was passed
